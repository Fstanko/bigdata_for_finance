# %% [markdown]
# # 🏦 Exercícios SQL — CVM Data Lake
# ### Versão do Aluno | Big Data for Finance — FAE
# **Banco:** PostgreSQL (DBeaver local)
#
# **Tabelas utilizadas:**
# - `layer_02_silver` — Tabelas que estão na camada Silver
#
# **CNPJs de referência rápida:**
# | Empresa | CNPJ |
# |---|---|
# | Petrobras | `33.000.167/0001-01` |
# | Ambev | `07.526.557/0001-00` |
# | Vale | `33.592.510/0001-54` |
#
# ---

# %% [markdown]
# ## ⚙️ Configuração da Conexão

# %%
Host: localhost
Porta: 5432
Database: bigdata_for_finance
Usuário: postgres
Senha: admin@1234

# %% [markdown]
# ---
# ## Questão 1 — Primeira olhada na tabela Silver 🟢 Fácil
# **Contexto:** A primeira coisa que um analista faz ao chegar em um novo banco é explorar o que existe dentro da tabela. A camada Silver já tem os dados do Balanço Patrimonial limpos, normalizados e prontos para análise.
#
# **Pergunta:** Mostre as **10 primeiras linhas** da tabela `n1_dfp_cia_aberta_bp`, exibindo apenas as colunas: `CNPJ_CIA`, `DENOM_CIA`, `DT_REFER`, `CD_CONTA`, `DS_CONTA`, `VL_CONTA_TRATADO` e `IS_LEAF`.

# %%
SELECT
    "CNPJ_CIA",
    "DENOM_CIA",
    "DT_REFER",
    "CD_CONTA",
    "DS_CONTA",
    "VL_CONTA_TRATADO",
    "IS_LEAF"
FROM layer_02_silver.n1_dfp_cia_aberta_bp
ORDER BY "DT_REFER" DESC
LIMIT 10;

#07.628.528/0001-59	BRASILAGRO - CIA BRAS DE PROP AGRICOLAS	2025-06-30 00:00:00.000	1.01.02.01.03	TÍTULOS E VALORES MOBILIÁRIOS	16908000	true
#07.628.528/0001-59	BRASILAGRO - CIA BRAS DE PROP AGRICOLAS	2025-06-30 00:00:00.000	1.01.03.02.02	ADIANTAMENTO A FORNECEDORES	429465000	true
#07.628.528/0001-59	BRASILAGRO - CIA BRAS DE PROP AGRICOLAS	2025-06-30 00:00:00.000	1.01.01	CAIXA E EQUIVALENTES DE CAIXA	142908000	false
#07.628.528/0001-59	BRASILAGRO - CIA BRAS DE PROP AGRICOLAS	2025-06-30 00:00:00.000	1.01.02.01	APLICAÇÕES FINANCEIRAS AVALIADAS A VALOR JUSTO ATRAVÉS DO RESULTADO	16908000	false
#07.628.528/0001-59	BRASILAGRO - CIA BRAS DE PROP AGRICOLAS	2025-06-30 00:00:00.000	1.01.03	CONTAS A RECEBER	429465000	false
#07.628.528/0001-59	BRASILAGRO - CIA BRAS DE PROP AGRICOLAS	2025-06-30 00:00:00.000	1.01.03.02	OUTRAS CONTAS A RECEBER	429465000	false
#07.628.528/0001-59	BRASILAGRO - CIA BRAS DE PROP AGRICOLAS	2025-06-30 00:00:00.000	1	ATIVO TOTAL	383700200	false
#07.628.528/0001-59	BRASILAGRO - CIA BRAS DE PROP AGRICOLAS	2025-06-30 00:00:00.000	1.01	ATIVO CIRCULANTE	1177848000	false
#07.628.528/0001-59	BRASILAGRO - CIA BRAS DE PROP AGRICOLAS	2025-06-30 00:00:00.000	1.01.02	APLICAÇÕES FINANCEIRAS	16908000	false
#07.628.528/0001-59	BRASILAGRO - CIA BRAS DE PROP AGRICOLAS	2025-06-30 00:00:00.000	1.01.04	ESTOQUES	293518000	false

# %% [markdown]
# ---
# ## Questão 2 — Volume e cobertura da base 🟢 Fácil
# **Contexto:** Antes de qualquer análise, o analista precisa entender o tamanho e a cobertura da base: quantas linhas existem, quantas empresas distintas estão cobertas e qual o intervalo de datas disponível.
#
# **Pergunta:** Em uma única query, calcule para a tabela `n1_dfp_cia_aberta_bp`:
# - Total de linhas → `total_linhas`
# - Quantidade de empresas distintas (por `CNPJ_CIA`) → `empresas_distintas`
# - Quantidade de datas de referência distintas (`DT_REFER`) → `datas_distintas`

# %%
SELECT 
    COUNT(*) AS total_linhas,
    COUNT(DISTINCT "CNPJ_CIA") AS empresas_distintas,
    COUNT(DISTINCT "DT_REFER") AS datas_distintas
FROM 
    layer_02_silver.n1_dfp_cia_aberta_bp;

# Total de linhas: 180461, empresas distintas: 185, datas distintas: 54

# %% [markdown]
# ---
# ## Questão 3 — Distribuição de empresas por setor 🟢 Fácil
# **Contexto:** A CVM classifica cada empresa listada em um setor de atividade (`SETOR_ATIV`). Entender essa distribuição é o ponto de partida para qualquer análise setorial comparativa. Use a tabela `n0_empresas_selecionadas`, que contém o cadastro completo das empresas do nosso universo.
#
# **Pergunta:** Quantas empresas existem em cada `SETOR_ATIV`? Ordene do setor com **mais** empresas para o com **menos**.

# %%
SELECT 
    "SETOR_ATIV", 
    COUNT(*) AS total_empresas
FROM 
    layer_02_silver.n0_empresas_selecionadas
GROUP BY 
    "SETOR_ATIV"
ORDER BY 
    total_empresas DESC;

#Energia Elétrica	33
#Construção Civil, Mat. Constr. e Decoração	30
#Comércio (Atacado e Varejo)	24
#Serviços Transporte e Logística	17
#Metalurgia e Siderurgia	13
#Têxtil e Vestuário	13
#Máquinas, Equipamentos, Veículos e Peças	13
#Alimentos	9
#Saneamento, Serv. Água e Gás	8
#Serviços Médicos	8
#Agricultura (Açúcar, Álcool e Cana)	7
#Comunicação e Informática	7
#Farmacêutico e Higiene	5
#Petroquímicos e Borracha	5
#Brinquedos e Lazer	4
#Petróleo e Gás	4
#Telecomunicações	4
#Educação	3
#Papel e Celulose	2
#Bolsas de Valores/Mercadorias e Futuros	1
#Bebidas e Fumo	   1
#Extração Mineral	1
#Hospedagem e Turismo	1
#Arrendamento Mercantil	1

# %% [markdown]
# ---
# ## Questão 4 — Petrobras: Ativo e Passivo mais recentes 🟢 Fácil
# **Contexto:** No Balanço Patrimonial da CVM, `CD_CONTA = '1'` é o **Ativo Total** e `CD_CONTA = '2'` é o **Passivo + Patrimônio Líquido Total**. A equação fundamental do BP é: **Ativo = Passivo + PL** — qualquer diferença indica erro de dados.
#
# **Pergunta:** Para a **Petrobras** (`CNPJ_CIA = '33.000.167/0001-01'`), mostre o valor (em bilhões de reais) das contas `'1'` e `'2'` para a **data de referência mais recente** disponível. Use uma subconsulta escalar com `MAX("DT_REFER")` para encontrar a data mais recente.
#
# *Dica: `ROUND((valor / 1e9)::NUMERIC, 2)` converte para bilhões com 2 casas.*

# %%
SELECT 
    "DS_CONTA",
    ROUND(("VL_CONTA_TRATADO" / 1e9)::NUMERIC, 2) AS valor_bilhoes
FROM 
    layer_02_silver.n1_dfp_cia_aberta_bp
WHERE 
    "CNPJ_CIA" = '33.000.167/0001-01'
    AND "CD_CONTA" IN ('1', '2')
    AND "DT_REFER" = (
        SELECT MAX("DT_REFER") 
        FROM layer_02_silver.n1_dfp_cia_aberta_bp 
        WHERE "CNPJ_CIA" = '33.000.167/0001-01'
    );

#ATIVO TOTAL	1124.80 bilhões
#PASSIVO TOTAL	1124.80 bilhões

# %% [markdown]
# ---
# ## Questão 5 — IS_LEAF: folhas vs. agregadores 🟢 Fácil
# **Contexto:** `IS_LEAF = TRUE` marca contas **analíticas** (sem filhos) — são as únicas que devem ser somadas em qualquer ferramenta de BI, pois evitam dupla contagem. `IS_LEAF = FALSE` são contas **sintéticas** (pais) que já incorporam os valores de todas as suas contas filhas. Somar tudo geraria dupla contagem.
#
# **Pergunta:** Para a **Petrobras** (`CNPJ_CIA = '33.000.167/0001-01'`) em `DT_REFER = '2023-12-31'`, quantas contas são `IS_LEAF = TRUE` e quantas são `IS_LEAF = FALSE`? Use `GROUP BY "IS_LEAF"`.

# %%
SELECT 
    "IS_LEAF", 
    COUNT(*) AS quantidade_contas
FROM 
    layer_02_silver.n1_dfp_cia_aberta_bp
WHERE 
    "CNPJ_CIA" = '33.000.167/0001-01' 
    AND "DT_REFER" = '2023-12-31'
GROUP BY 
    "IS_LEAF";

#false	51
#true	19

# %% [markdown]
# ---
# ## Questão 6 — Top 10 maiores empresas por Ativo Total em 2023 🟡 Médio
# **Contexto:** Rankings de tamanho de balanço são análises clássicas de mercado de capitais. O Ativo Total (`CD_CONTA = '1'`) resume o tamanho total de uma empresa — tudo que ela possui e tem direito a receber.
#
# **Pergunta:** Liste as **10 empresas com maior Ativo Total** em `DT_REFER = '2023-12-31'`. Exiba `DENOM_CIA`, `SETOR_ATIV` e o valor em **bilhões** (2 casas decimais). Ordene do maior para o menor.
#
# *Dica: `ROUND((expr)::NUMERIC, 2)` — o cast para `NUMERIC` é obrigatório no PostgreSQL quando a coluna é `DOUBLE PRECISION`.*

# %%
SELECT 
    t1."DENOM_CIA", 
    t2."SETOR_ATIV",
    ROUND((t1."VL_CONTA_TRATADO" / 1e9)::NUMERIC, 2) AS ativo_total_bilhoes
FROM 
    layer_02_silver.n1_dfp_cia_aberta_bp AS t1
JOIN 
    layer_02_silver.n0_empresas_selecionadas AS t2 ON t1."CNPJ_CIA" = t2."CNPJ_CIA"
WHERE 
    t1."CD_CONTA" = '1' 
    AND t1."DT_REFER" = '2023-12-31'
ORDER BY 
    ativo_total_bilhoes DESC
LIMIT 10;

#PETROLEO BRASILEIRO S.A. PETROBRAS	Petróleo e Gás	1050.89 bilhões
#VALE S.A.	Extração Mineral	455.98 bilhões
#JBS S.A.	Alimentos	206.13 bilhões
#SUZANO S.A.	Papel e Celulose	143.59 bilhões
#COSAN S.A.	Agricultura (Açúcar, Álcool e Cana)	139.87 bilhões
#AMBEV S.A.	Bebidas e Fumo	132.64 bilhões
#MARFRIG GLOBAL FOODS S.A.	Alimentos	130.95 bilhões
#TELEFÔNICA BRASIL S.A	Telecomunicações	120.74 bilhões
#EQUATORIAL S.A.	Energia Elétrica	103.64 bilhões
#BRASKEM S.A.	Petroquímicos e Borracha	91.74 bilhões

# %% [markdown]
# ---
# ## Questão 7 — Evolução anual do Ativo Total da Ambev 🟡 Médio
# **Contexto:** Acompanhar a evolução do balanço ao longo dos anos revela a trajetória de crescimento (ou retração) de uma empresa. `DT_REFER` é do tipo `TIMESTAMP` — use `EXTRACT(YEAR FROM ...)` para extrair o ano.
#
# **Pergunta:** Para a **Ambev** (`CNPJ_CIA = '07.526.557/0001-00'`), mostre a evolução anual do **Ativo Total** (`CD_CONTA = '1'`). Extraia o ano de `DT_REFER`, exiba o valor em bilhões e ordene do ano mais antigo ao mais recente.

# %%
SELECT 
    EXTRACT(YEAR FROM "DT_REFER") AS ano,
    ROUND(("VL_CONTA_TRATADO" / 1e9)::NUMERIC, 2) AS ativo_total_bilhoes
FROM 
    layer_02_silver.n1_dfp_cia_aberta_bp
WHERE 
    "CNPJ_CIA" = '07.526.557/0001-00' 
    AND "CD_CONTA" = '1'
ORDER BY 
    ano ASC;

#2013	68.67 bilhões
#2014	72.14 bilhões
#2015	90.18 bilhões
#2016	83.84 bilhões
#2017	86.85 bilhões
#2018	94.13 bilhões
#2019	101.74 bilhões
#2020	125.20 bilhões
#2021	138.60 bilhões
#2022	137.96 bilhões
#2023	132.64 bilhões
#2024	162.51 bilhões

# %% [markdown]
# ---
# ## Questão 8 — Contas reconstruídas pelo pipeline 🟡 Médio
# **Contexto:** `FLAG_RECONSTRUCAO = TRUE` indica que uma linha foi criada **sinteticamente** pelo pipeline — a empresa não reportou aquela conta e o pipeline reconstruiu o valor somando os filhos. Mais contas reconstruídas = mais "buracos" no dado original enviado à CVM.
#
# **Pergunta:** Em **toda a base histórica**, quais são as **10 combinações de empresa e data** com mais contas reconstruídas no BP? Mostre `DT_REFER`, `DENOM_CIA` e o total de contas de cada empresa. Use `SUM(CASE WHEN "FLAG_RECONSTRUCAO" = TRUE THEN 1 ELSE 0 END)` para contar. Agrupe por `"DT_REFER"` e `"DENOM_CIA"`. Ordene da mais para a menos reconstruída.

# %%
SELECT 
    "DT_REFER", 
    "DENOM_CIA", 
    SUM(CASE WHEN "FLAG_RECONSTRUCAO" = TRUE THEN 1 ELSE 0 END) AS total_contas_reconstruidas
FROM 
    layer_02_silver.n1_dfp_cia_aberta_bp
GROUP BY 
    "DT_REFER", 
    "DENOM_CIA"
ORDER BY 
    total_contas_reconstruidas DESC
LIMIT 10;

#2022-12-31 	CESP - CIA ENERGETICA DE SAO PAULO	15
#2021-12-31 	VIVER INCORPORADORA E CONSTRUTORA S.A.	2
#2017-12-31 	CIA SIDERURGICA NACIONAL	1
#2010-12-31 	USINAS SID DE MINAS GERAIS S.A.-USIMINAS	1
#2016-12-31 	CIA SIDERURGICA NACIONAL	1
#2021-12-31 	INTERNATIONAL MEAL COMPANY ALIMENTACAO S.A.	1
#2022-12-31 	GRUPO CASAS BAHIA S.A.	1
#2022-12-31	    CIA BRASILEIRA DE DISTRIBUICAO	１
#2021-12-31 	CVC BRASIL OPERADORA E AGÊNCIA DE VIAGENS S.A.	１
#2018-12-31	    PRIO S.A.	０

# %% [markdown]
# ---
# ## Questão 9 — Base analítica de Receita Bruta por empresa via JOIN 🟡 Médio
# **Contexto:** Antes de agregar, o analista precisa da base analítica: uma linha por empresa com seu setor e receita. Com esse DataFrame em mãos, o Pandas consegue gerar estatísticas descritivas por grupo com `.describe()`.
#
# **Pergunta:** Faça um `JOIN` entre `n1_dfp_cia_aberta_dre` e `n0_empresas_selecionadas`. Para `DT_REFER = '2023-12-31'` e `CD_CONTA = '3.01'` (Receita Bruta), traga uma linha por empresa com `CNPJ_CIA`, `DENOM_CIA`, `SETOR_ATIV` e o valor em bilhões. Depois use `.groupby` + `.describe()` para ver as estatísticas por setor.

# %%
SELECT 
    t1."CNPJ_CIA", 
    t1."DENOM_CIA", 
    t2."SETOR_ATIV",
    ROUND((t1."VL_CONTA_TRATADO" / 1e9)::NUMERIC, 2) AS receita_bruta_bilhoes
FROM 
    layer_02_silver.n1_dfp_cia_aberta_dre AS t1
JOIN 
    layer_02_silver.n0_empresas_selecionadas AS t2 ON t1."CNPJ_CIA" = t2."CNPJ_CIA"
WHERE 
    t1."CD_CONTA" = '3.01' 
    AND t1."DT_REFER" = '2023-12-31';

#07.206.816/0001-15	M.DIAS BRANCO S.A. IND COM DE ALIMENTOS	Alimentos	10.84
#07.415.333/0001-20	SIMPAR S.A.	Serviços Transporte e Logística	31.84
#07.526.557/0001-00	AMBEV S.A.	Bebidas e Fumo	79.74
#07.594.978/0001-78	SMARTFIT ESCOLA DE GINÁSTICA E DANÇA S.A.	Brinquedos e Lazer	4.24
#07.689.002/0001-89	EMBRAER S.A.	Máquinas, Equipamentos, Veículos e Peças	26.11
#07.820.907/0001-46	FICA EMPREENDIMENTOS IMOBILIÁRIOS S.A.	Construção Civil, Mat. Constr. e Decoração	0.00
#07.882.930/0001-65	MITRE REALTY EMPREENDIMENTOS E PARTICIPAÇÕES S.A.	Construção Civil, Mat. Constr. e Decoração	0.93
#08.065.557/0001-12	TECNISA S.A.	Construção Civil, Mat. Constr. e Decoração	0.44
#08.159.965/0001-33	IGUA SANEAMENTO S.A.	Saneamento, Serv. Água e Gás	2.34
#08.343.492/0001-20	MRV ENGENHARIA E PARTICIPACOES S.A.	Construção Civil, Mat. Constr. e Decoração	7.43
#08.402.943/0001-52	GUARARAPES CONFECCOES S.A.	Têxtil e Vestuário	8.80
#08.764.621/0001-53	GENERAL SHOPPING E OUTLETS DO BRASIL BRASIL S.A.	Comércio (Atacado e Varejo)	0.16
#08.797.760/0001-83	CURY CONSTRUTORA E INCORPORADORA S.A.	Construção Civil, Mat. Constr. e Decoração	2.89
#09.041.168/0001-10	LOG COMMERCIAL PROPERTIES E PARTICIPAÇÕES	Construção Civil, Mat. Constr. e Decoração	0.22
#09.042.817/0001-05	BEMOBI MOBILE TECH S.A.	Comunicação e Informática	1.31
#09.114.805/0001-30	OCEANPACT SERVIÇOS MARITIMOS S.A.	Petróleo e Gás	1.65
#09.288.252/0001-32	ANIMA HOLDING S.A.	Educação	3.73
#09.295.063/0001-97	TECHNOS S.A.	Comércio (Atacado e Varejo)	0.34
#09.346.601/0001-25	B3 S.A. - BRASIL, BOLSA, BALCÃO	Bolsas de Valores/Mercadorias e Futuros	9.92
#09.611.768/0001-76	INC EMPREENDIMENTOS IMOBILIÁRIOS S.A.	Construção Civil, Mat. Constr. e Decoração	0.49
#10.629.105/0001-68	PRIO S.A.	Petróleo e Gás	11.91
